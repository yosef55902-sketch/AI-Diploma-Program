# %% [markdown]
# # Exercise 02
#
# **Module 01**
#
# ---

# %% [markdown]
# Exercise 02: Matrix Properties and OperationsThis exercise focuses on understanding matrix properties that are importantfor machine learning, such as determinants, inverses, and eigenvalues.Instructions:1. Complete the functions below2. Understand what each property means for ML3. Test your solutions

# %% [markdown]
# ---
#
# ## ⚠️ Important: Implement Functions First!
#
# **Before running tests**, complete all function implementations:
#
# 1. ✅ Find all functions with `pass` statements
# 2. ✅ Replace `pass` with your implementation
# 3. ✅ Make sure functions return values (not None)
#
# **The test code will give helpful hints if you forget!**

# %% [markdown]
# ---
#
# ## 📝 Your Implementation
#
# Complete the functions below. Replace `pass` with your code:

# %%
import numpy as npdef compute_determinant(matrix):        # TODO: Compute determinant using np.linalg.det()    passdef compute_matrix_inverse(matrix):        # TODO: Compute inverse using np.linalg.inv()    # Note: Matrix must be square and have non-zero determinant    passdef compute_eigenvalues_eigenvectors(matrix):        # TODO: Use np.linalg.eig() to compute eigenvalues and eigenvectors    passdef verify_inverse(matrix, inverse):        # TODO: Multiply matrix by inverse and check if result is identity    # Use np.allclose() for floating point comparison    pass# Test your solutions

# %% [markdown]
# ---
#
# ## 🧪 Test Your Solution
#
# **Run this after implementing all functions above:**

# %%
if __name__ == "__main__":    print("Testing Exercise 02: Matrix Properties")    print("=" * 60)        # Test 1: Determinant    print("\n1. Testing compute_determinant:")    matrix = np.array([[1, 2], [3, 4]])    det = compute_determinant(matrix)    expected = -2.0  # 1*4 - 2*3 = 4 - 6 = -2    print(f"   Determinant: {det:.2f}")    print(f"   Expected: {expected:.2f}")    assert np.isclose(det, expected), "Determinant incorrect"    print("   ✅ Passed!")        # Test 2: Matrix inverse    print("\n2. Testing compute_matrix_inverse:")    matrix = np.array([[1, 2], [3, 4]])    inv = compute_matrix_inverse(matrix)    expected = np.array([[-2.0, 1.0], [1.5, -0.5]])    print(f"   Inverse:\n{inv}")    print(f"   Expected:\n{expected}")    assert np.allclose(inv, expected), "Inverse incorrect"    print("   ✅ Passed!")        # Test 3: Verify inverse    print("\n3. Testing verify_inverse:")    is_valid = verify_inverse(matrix, inv)    print(f"   Matrix @ Inverse = Identity: {is_valid}")    assert is_valid, "Inverse verification failed"    print("   ✅ Passed!")        # Test 4: Eigenvalues and eigenvectors    print("\n4. Testing compute_eigenvalues_eigenvectors:")    matrix = np.array([[2, 1], [1, 2]])    eigenvals, eigenvecs = compute_eigenvalues_eigenvectors(matrix)    print(f"   Eigenvalues: {eigenvals}")    print(f"   Eigenvectors:\n{eigenvecs}")    print("   ✅ Computed successfully!")        print("\n" + "=" * 60)    print("🎉 All tests passed!")

# %% [markdown]
# ---
#
# ## ✅ Check Solution
#
# Compare with: `exercises/solutions/solution_02.ipynb`
#
# **💡 Try solving it yourself first!**
